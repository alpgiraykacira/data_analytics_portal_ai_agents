# %%
import dotenv

from logger import setup_logger
from langchain_core.messages import HumanMessage
from core.workflow import Workflow
from core.llm import LLM

dotenv.load_dotenv()

class DataAnalyticsPortal:
    def __init__(self):
        self.logger = setup_logger()
        self.llm = LLM()
        self.workflow = Workflow(
            llms=self.llm.get_models(),
        )

    def run(self, user_input: str) -> None:
        """Run the system with user input"""
        graph = self.workflow.get_graph()
        events = graph.stream(
            {
                "messages": [HumanMessage(content=user_input)],
                "process_state": "",
                "process_decision": "",
                "query_state": "",
                "retrieval_state": "",
                "api_state": "",
                "analysis_state": "",
                "visualization_state": "",
                "report_state": "",
                "sender": "",
            },
            {"configurable": {"thread_id": "1"}, "recursion_limit": 30},
            stream_mode="values",
            debug=False
        )

        for event in events:
            message = event["messages"][-1]
            if isinstance(message, tuple):
                print(message, end='', flush=True)
            else:
                message.pretty_print()



system = DataAnalyticsPortal()

user_input = '''
2024 yılı ilk 6 ayında Osmaniye ilindeki planlı elektrik kesintileri
'''
system.run(user_input)
# Out:
# 2025-06-10 17:46:17,469 - logger - INFO - Agent creation module initialized
# 2025-06-10 17:46:29,359 - logger - INFO - Language models initialized successfully.
# 2025-06-10 17:46:29,360 - logger - INFO - Creating agent
# 2025-06-10 17:46:29,370 - logger - INFO - Agent created successfully
# 2025-06-10 17:46:29,371 - logger - INFO - Creating agent
# 2025-06-10 17:46:29,375 - logger - INFO - Agent created successfully
# 2025-06-10 17:46:29,376 - logger - INFO - Creating agent
# 2025-06-10 17:46:29,385 - logger - INFO - Agent created successfully
# 2025-06-10 17:46:29,386 - logger - INFO - Creating supervisor
# 2025-06-10 17:46:29,387 - logger - INFO - Supervisor created successfully
# c:\Users\alpgi\Desktop\desktop-mix\project\project\data_analytics_portal_ai_agents\core\agent.py:127: LangChainDeprecationWarning: The method `BaseChatOpenAI.bind_functions` was deprecated in langchain-openai 0.2.1 and will be removed in 1.0.0. Use :meth:`~langchain_openai.chat_models.base.ChatOpenAI.bind_tools` instead.
#   | llm.bind_functions(functions=[function_def], function_call="route")
# 2025-06-10 17:46:29,390 - logger - INFO - Creating agent
# 2025-06-10 17:46:29,395 - logger - INFO - Agent created successfully
# 2025-06-10 17:46:29,396 - logger - INFO - Creating agent
# 2025-06-10 17:46:29,400 - logger - INFO - Agent created successfully
# 2025-06-10 17:46:29,401 - logger - INFO - Creating agent
# 2025-06-10 17:46:29,406 - logger - INFO - Agent created successfully
# 2025-06-10 17:46:29,650 - logger - INFO - Processing agent: query_agent
# ================================ Human Message =================================
#
#
# 2024 yılı ilk 6 ayında Osmaniye ilindeki planlı elektrik kesintileri
# 2025-06-10 17:46:33,090 - logger - INFO - Query state updated
# 2025-06-10 17:46:33,092 - logger - INFO - Agent query_agent processing completed
# 2025-06-10 17:46:33,102 - logger - INFO - Processing agent: retrieval_agent
# ================================== Ai Message ==================================
# Name: query_agent
#
# {
#   "intent": "get data - return data",
#   "parameters": {
#     "startDate": "2024-01-01T00:00:00+03:00",
#     "endDate": "2024-06-30T00:00:00+03:00",
#     "province_id": 800,
#     "dataTypes": ["planned power outages"],
#     "workflow": "get data - return data",
#     "operationType": null,
#     "chartType": null
#   }
# }
# 2025-06-10 17:46:52,360 - logger - INFO - Retrieval state updated
# 2025-06-10 17:46:52,361 - logger - INFO - Agent retrieval_agent processing completed
# 2025-06-10 17:46:52,367 - logger - INFO - Processing agent: api_agent
# ================================== Ai Message ==================================
# Name: retrieval_agent
#
# {
#   "api_calls": [
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/planned-power-outage-info",
#       "body": {
#         "period": "2024-01-01T00:00:00+03:00",
#         "provinceId": 800
#       }
#     },
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/planned-power-outage-info",
#       "body": {
#         "period": "2024-02-01T00:00:00+03:00",
#         "provinceId": 800
#       }
#     },
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/planned-power-outage-info",
#       "body": {
#         "period": "2024-03-01T00:00:00+03:00",
#         "provinceId": 800
#       }
#     },
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/planned-power-outage-info",
#       "body": {
#         "period": "2024-04-01T00:00:00+03:00",
#         "provinceId": 800
#       }
#     },
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/planned-power-outage-info",
#       "body": {
#         "period": "2024-05-01T00:00:00+03:00",
#         "provinceId": 800
#       }
#     },
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/planned-power-outage-info",
#       "body": {
#         "period": "2024-06-01T00:00:00+03:00",
#         "provinceId": 800
#       }
#     }
#   ]
# }
# 2025-06-10 17:47:13,637 - logger - INFO - Calling EPIAS API: POST https://seffaflik.epias.com.tr/electricity-service/v1/consumption/data/planned-power-outage-info with body={'period': '2024-01-01T00:00:00+03:00', 'provinceId': 800}
# 2025-06-10 17:47:13,844 - logger - INFO - API call successful, returning compact JSON: {"items":[],"page":null}
# 2025-06-10 17:47:25,182 - logger - INFO - Calling EPIAS API: POST https://seffaflik.epias.com.tr/electricity-service/v1/consumption/data/planned-power-outage-info with body={'period': '2024-02-01T00:00:00+03:00', 'provinceId': 800}
# 2025-06-10 17:47:25,349 - logger - INFO - API call successful, returning compact JSON: {"items":[],"page":null}
# 2025-06-10 17:47:37,661 - logger - INFO - Calling EPIAS API: POST https://seffaflik.epias.com.tr/electricity-service/v1/consumption/data/planned-power-outage-info with body={'period': '2024-03-01T00:00:00+03:00', 'provinceId': 800}
# 2025-06-10 17:47:37,840 - logger - INFO - API call successful, returning compact JSON: {"items":[{"province":"OSMANİYE","district":"Osmaniye Merkez","date":"2024-03-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-03-01T11:00:00+03:00","endTime":"2024-03-01T17:15:00+03:00","reason":"Hizmet Alım Çalışması - YG-hizmet alım çalışmaları","effectedNeighbourhoods":"CUMHURİYET Mah.","effectedSubscribers":572,"hourlyLoadAvg":161,"id":6974612},{"province":"OSMANİYE","district":"Osmaniye Merkez","date":"2024-03-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-03-01T09:15:00+03:00","endTime":"2024-03-01T17:00:00+03:00","reason":"Hizmet Alım Çalışması - YG-hizmet alım çalışmaları","effectedNeighbourhoods":"KÖYÜN KENDİSİ Mah.","effectedSubscribers":6162,"hourlyLoadAvg":1911,"id":6974635},{"province":"OSMANİYE","district":"Toprakkale","date":"2024-03-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-03-01T09:00:00+03:00","endTime":"2024-03-01T15:00:00+03:00","reason":" - ","effectedNeighbourhoods":"FATIH SULTAN MEHMET Mah.","effectedSubscribers":107,"hourlyLoadAvg":42,"id":6974606}],"page":null}
# 2025-06-10 17:47:52,056 - logger - INFO - Calling EPIAS API: POST https://seffaflik.epias.com.tr/electricity-service/v1/consumption/data/planned-power-outage-info with body={'period': '2024-04-01T00:00:00+03:00', 'provinceId': 800}
# 2025-06-10 17:47:52,239 - logger - INFO - API call successful, returning compact JSON: {"items":[{"province":"OSMANİYE","district":"Osmaniye Merkez","date":"2024-04-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-04-01T09:15:00+03:00","endTime":"2024-04-01T14:00:00+03:00","reason":"Hizmet Alım Çalışması - YG-hizmet alım çalışmaları","effectedNeighbourhoods":"CUMHURİYET Mah.","effectedSubscribers":573,"hourlyLoadAvg":162,"id":7100899},{"province":"OSMANİYE","district":"Düziçi","date":"2024-04-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-04-01T09:00:00+03:00","endTime":"2024-04-01T17:00:00+03:00","reason":" - ","effectedNeighbourhoods":"ARPAÇUKURU Mah.","effectedSubscribers":439,"hourlyLoadAvg":80,"id":7100901}],"page":null}
# 2025-06-10 17:48:04,792 - logger - INFO - Calling EPIAS API: POST https://seffaflik.epias.com.tr/electricity-service/v1/consumption/data/planned-power-outage-info with body={'period': '2024-05-01T00:00:00+03:00', 'provinceId': 800}
# 2025-06-10 17:48:04,987 - logger - INFO - API call successful, returning compact JSON: {"items":[],"page":null}
# 2025-06-10 17:48:18,685 - logger - INFO - Calling EPIAS API: POST https://seffaflik.epias.com.tr/electricity-service/v1/consumption/data/planned-power-outage-info with body={'period': '2024-06-01T00:00:00+03:00', 'provinceId': 800}
# 2025-06-10 17:48:18,901 - logger - INFO - API call successful, returning compact JSON: {"items":[{"province":"OSMANİYE","district":"Osmaniye Merkez","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T13:30:00+03:00","endTime":"2024-06-01T17:00:00+03:00","reason":"Tesis Çalışması - Tesis","effectedNeighbourhoods":"M.FEVZİ ÇAKMAK Mah.","effectedSubscribers":108,"hourlyLoadAvg":36,"id":7417692},{"province":"OSMANİYE","district":"Osmaniye Merkez","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T09:30:00+03:00","endTime":"2024-06-01T17:00:00+03:00","reason":"Tesis Çalışması - Tesis","effectedNeighbourhoods":"KAZIM KARABEKİR Mah.","effectedSubscribers":186,"hourlyLoadAvg":66,"id":7417704},{"province":"OSMANİYE","district":"Osmaniye Merkez","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T09:45:00+03:00","endTime":"2024-06-01T17:15:00+03:00","reason":"Tesis Çalışması - Tesis","effectedNeighbourhoods":"M.FEVZİ ÇAKMAK Mah.","effectedSubscribers":337,"hourlyLoadAvg":114,"id":7417708},{"province":"OSMANİYE","district":"Osmaniye Merkez","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T09:30:00+03:00","endTime":"2024-06-01T17:00:00+03:00","reason":"Tesis Çalışması - Tesis","effectedNeighbourhoods":"MEVLANA Mah.","effectedSubscribers":37,"hourlyLoadAvg":18,"id":7417719},{"province":"OSMANİYE","district":"Hasanbeyli","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T09:15:00+03:00","endTime":"2024-06-01T17:15:00+03:00","reason":"Hizmet Alım Çalışması - YG-hizmet alım çalışmaları","effectedNeighbourhoods":"KÖYÜN KENDİSİ Mah.","effectedSubscribers":326,"hourlyLoadAvg":93,"id":7417690}],"page":null}
# 2025-06-10 17:49:25,172 - logger - INFO - API state updated
# 2025-06-10 17:49:25,176 - logger - INFO - Agent api_agent processing completed
# 2025-06-10 17:49:25,188 - logger - INFO - Processing agent: process_agent
# ================================== Ai Message ==================================
# Name: api_agent
#
# compact_json:{"items":[{"province":"OSMANİYE","district":"OsmaniyeMerkez","date":"2024-03-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-03-01T11:00:00+03:00","endTime":"2024-03-01T17:15:00+03:00","reason":"HizmetAlımÇalışması-YG-hizmetalımçalışmaları","effectedNeighbourhoods":"CUMHURİYETMah.","effectedSubscribers":572,"hourlyLoadAvg":161,"id":6974612},{"province":"OSMANİYE","district":"OsmaniyeMerkez","date":"2024-03-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-03-01T09:15:00+03:00","endTime":"2024-03-01T17:00:00+03:00","reason":"HizmetAlımÇalışması-YG-hizmetalımçalışmaları","effectedNeighbourhoods":"KÖYÜNKENDİSİMah.","effectedSubscribers":6162,"hourlyLoadAvg":1911,"id":6974635},{"province":"OSMANİYE","district":"Toprakkale","date":"2024-03-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-03-01T09:00:00+03:00","endTime":"2024-03-01T15:00:00+03:00","reason":"-","effectedNeighbourhoods":"FATIHSULTANMEHMETMah.","effectedSubscribers":107,"hourlyLoadAvg":42,"id":6974606},{"province":"OSMANİYE","district":"OsmaniyeMerkez","date":"2024-04-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-04-01T09:15:00+03:00","endTime":"2024-04-01T14:00:00+03:00","reason":"HizmetAlımÇalışması-YG-hizmetalımçalışmaları","effectedNeighbourhoods":"CUMHURİYETMah.","effectedSubscribers":573,"hourlyLoadAvg":162,"id":7100899},{"province":"OSMANİYE","district":"Düziçi","date":"2024-04-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-04-01T09:00:00+03:00","endTime":"2024-04-01T17:00:00+03:00","reason":"-","effectedNeighbourhoods":"ARPAÇUKURUMah.","effectedSubscribers":439,"hourlyLoadAvg":80,"id":7100901},{"province":"OSMANİYE","district":"OsmaniyeMerkez","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T13:30:00+03:00","endTime":"2024-06-01T17:00:00+03:00","reason":"TesisÇalışması-Tesis","effectedNeighbourhoods":"M.FEVZİÇAKMAKMah.","effectedSubscribers":108,"hourlyLoadAvg":36,"id":7417692},{"province":"OSMANİYE","district":"OsmaniyeMerkez","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T09:30:00+03:00","endTime":"2024-06-01T17:00:00+03:00","reason":"TesisÇalışması-Tesis","effectedNeighbourhoods":"KAZIMKARABEKİRMah.","effectedSubscribers":186,"hourlyLoadAvg":66,"id":7417704},{"province":"OSMANİYE","district":"OsmaniyeMerkez","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T09:45:00+03:00","endTime":"2024-06-01T17:15:00+03:00","reason":"TesisÇalışması-Tesis","effectedNeighbourhoods":"M.FEVZİÇAKMAKMah.","effectedSubscribers":337,"hourlyLoadAvg":114,"id":7417708},{"province":"OSMANİYE","district":"OsmaniyeMerkez","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T09:30:00+03:00","endTime":"2024-06-01T17:00:00+03:00","reason":"TesisÇalışması-Tesis","effectedNeighbourhoods":"MEVLANAMah.","effectedSubscribers":37,"hourlyLoadAvg":18,"id":7417719},{"province":"OSMANİYE","district":"Hasanbeyli","date":"2024-06-01T00:00:00+03:00","distributionCompanyName":"TOROSLAR_EDAS","startTime":"2024-06-01T09:15:00+03:00","endTime":"2024-06-01T17:15:00+03:00","reason":"HizmetAlımÇalışması-YG-hizmetalımçalışmaları","effectedNeighbourhoods":"KÖYÜNKENDİSİMah.","effectedSubscribers":326,"hourlyLoadAvg":93,"id":7417690}]}
# 2025-06-10 17:49:28,212 - logger - INFO - Process decision and state updated
# 2025-06-10 17:49:28,215 - logger - INFO - Agent process_agent processing completed
# 2025-06-10 17:49:28,226 - logger - INFO - Entering process_router
# 2025-06-10 17:49:28,229 - logger - INFO - Processed decision: FINISH
# 2025-06-10 17:49:28,231 - logger - INFO - Process decision is FINISH. Ending process.
# ================================== Ai Message ==================================
# Name: process_agent
#
# {'next': 'FINISH', 'task': 'Verilen veri doğrudan iletildi, başka bir analiz veya görselleştirme gerekmiyor.'}
