# %%
import dotenv
from logger import setup_logger
from langchain_core.messages import HumanMessage
from core.workflow import Workflow
from core.llm import LLM

dotenv.load_dotenv()

class DataAnalyticsPortal:
    def __init__(self):
        self.logger = setup_logger()
        self.llm = LLM()
        self.workflow = Workflow(
            llms=self.llm.get_models(),
        )

    def run(self, user_input: str) -> None:
        """Run the system with user input"""
        graph = self.workflow.get_graph()
        events = graph.stream(
            {
                "messages": [HumanMessage(content=user_input)],
                "process_state": "",
                "process_decision": "",
                "query_state": "",
                "retrieval_state": "",
                "api_state": "",
                "analysis_state": "",
                "visualization_state": "",
                "report_state": "",
                "sender": "",
            },
            {"configurable": {"thread_id": "1"}, "recursion_limit": 30},
            stream_mode="values",
            debug=False
        )

        for event in events:
            message = event["messages"][-1]
            if isinstance(message, tuple):
                print(message, end='', flush=True)
            else:
                message.pretty_print()


def main():
    system = DataAnalyticsPortal()

    user_input = '''
    son 2 günde Istanbul avrupa ve asya kıtalarının elektrik tüketimlerinin karşılaştırılması
    '''
    system.run(user_input)


if __name__ == "__main__":
    main()
# Out:
# 2025-05-28 23:28:13,119 - logger - INFO - Agent creation module initialized
# 2025-05-28 23:28:27,149 - logger - INFO - Language models initialized successfully.
# 2025-05-28 23:28:27,150 - logger - INFO - Creating agent
# 2025-05-28 23:28:27,170 - logger - INFO - Agent created successfully
# 2025-05-28 23:28:27,171 - logger - INFO - Creating agent
# 2025-05-28 23:28:27,176 - logger - INFO - Agent created successfully
# 2025-05-28 23:28:27,177 - logger - INFO - Creating agent
# 2025-05-28 23:28:27,310 - logger - INFO - Agent created successfully
# 2025-05-28 23:28:27,311 - logger - INFO - Creating supervisor
# 2025-05-28 23:28:27,312 - logger - INFO - Supervisor created successfully
# C:\Users\alpgi\Desktop\project\project\data_analytics_portal_ai_agents\core\agent.py:127: LangChainDeprecationWarning: The method `BaseChatOpenAI.bind_functions` was deprecated in langchain-openai 0.2.1 and will be removed in 1.0.0. Use :meth:`~langchain_openai.chat_models.base.ChatOpenAI.bind_tools` instead.
#   | llm.bind_functions(functions=[function_def], function_call="route")
# 2025-05-28 23:28:27,315 - logger - INFO - Creating agent
# 2025-05-28 23:28:27,320 - logger - INFO - Agent created successfully
# 2025-05-28 23:28:27,322 - logger - INFO - Creating agent
# 2025-05-28 23:28:27,327 - logger - INFO - Agent created successfully
# 2025-05-28 23:28:27,328 - logger - INFO - Creating agent
# 2025-05-28 23:28:27,339 - logger - INFO - Agent created successfully
# 2025-05-28 23:28:27,681 - logger - INFO - Processing agent: query_agent
# ================================ Human Message =================================
#
#
#     son 2 günde Istanbul avrupa ve asya kıtalarının elektrik tüketimlerinin karşılaştırılması
# 2025-05-28 23:28:31,134 - logger - INFO - Query state updated
# 2025-05-28 23:28:31,136 - logger - INFO - Agent query_agent processing completed
# 2025-05-28 23:28:31,141 - logger - INFO - Processing agent: retrieval_agent
# ================================== Ai Message ==================================
# Name: query_agent
#
# {
#   "intent": "get data - return visualization - return report",
#   "parameters": {
#     "startDate": "2024-06-06T00:00:00+03:00",
#     "endDate": "2024-06-07T23:59:59+03:00",
#     "province_id": [341, 340],
#     "dataTypes": ["electricity consumption"],
#     "workflow": "get data - return visualization - return report",
#     "operationType": "comparison",
#     "chartType": "bar"
#   }
# }
# 2025-05-28 23:28:37,073 - logger - INFO - Retrieval state updated
# 2025-05-28 23:28:37,074 - logger - INFO - Agent retrieval_agent processing completed
# 2025-05-28 23:28:37,079 - logger - INFO - Processing agent: api_agent
# ================================== Ai Message ==================================
# Name: retrieval_agent
#
# {
#   "api_calls": [
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/consumption-quantity",
#       "body": {
#         "period": "2024-06-06T00:00:00+03:00",
#         "provinceId": 341
#       }
#     },
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/consumption-quantity",
#       "body": {
#         "period": "2024-06-07T00:00:00+03:00",
#         "provinceId": 341
#       }
#     },
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/consumption-quantity",
#       "body": {
#         "period": "2024-06-06T00:00:00+03:00",
#         "provinceId": 340
#       }
#     },
#     {
#       "method": "POST",
#       "service": "/electricity-service",
#       "endpoint": "/v1/consumption/data/consumption-quantity",
#       "body": {
#         "period": "2024-06-07T00:00:00+03:00",
#         "provinceId": 340
#       }
#     }
#   ]
# }
# 2025-05-28 23:28:39,400 - logger - INFO - Calling EPIAS API with method: POST, endpoint: https://seffaflik.epias.com.tr//electricity-service/v1/consumption/data/consumption-quantity, body: {'period': '2024-06-06T00:00:00+03:00', 'provinceId': 341}
# 2025-05-28 23:28:39,570 - logger - INFO - API call completed with status code: 200
# 2025-05-28 23:28:41,076 - logger - INFO - Calling EPIAS API with method: POST, endpoint: https://seffaflik.epias.com.tr//electricity-service/v1/consumption/data/consumption-quantity, body: {'period': '2024-06-07T00:00:00+03:00', 'provinceId': 341}
# 2025-05-28 23:28:41,206 - logger - INFO - API call completed with status code: 200
# 2025-05-28 23:28:42,640 - logger - INFO - Calling EPIAS API with method: POST, endpoint: https://seffaflik.epias.com.tr//electricity-service/v1/consumption/data/consumption-quantity, body: {'period': '2024-06-06T00:00:00+03:00', 'provinceId': 340}
# 2025-05-28 23:28:42,762 - logger - INFO - API call completed with status code: 200
# 2025-05-28 23:28:45,096 - logger - INFO - Calling EPIAS API with method: POST, endpoint: https://seffaflik.epias.com.tr//electricity-service/v1/consumption/data/consumption-quantity, body: {'period': '2024-06-07T00:00:00+03:00', 'provinceId': 340}
# 2025-05-28 23:28:45,229 - logger - INFO - API call completed with status code: 200
# 2025-05-28 23:29:14,077 - logger - INFO - API state updated
# 2025-05-28 23:29:14,078 - logger - INFO - Agent api_agent processing completed
# 2025-05-28 23:29:14,083 - logger - INFO - Processing agent: process_agent
# ================================== Ai Message ==================================
# Name: api_agent
#
# ```json
# {
#     "response": {
#         "Istanbul_Europe": {
#             "2024-06-06": {
#                 "Lighting": {
#                     "serbestTuketiciTuketimMiktari": 828,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 18328,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 606
#                 },
#                 "Other": {
#                     "serbestTuketiciTuketimMiktari": 0,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 10,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 803
#                 },
#                 "Household": {
#                     "serbestTuketiciTuketimMiktari": 352,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 28023,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 621182
#                 },
#                 "Industry": {
#                     "serbestTuketiciTuketimMiktari": 411813,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 382,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 21312
#                 },
#                 "Irrigation": {
#                     "serbestTuketiciTuketimMiktari": 55,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 16,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 323
#                 },
#                 "Commercial": {
#                     "serbestTuketiciTuketimMiktari": 618548,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 22710,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 382440
#                 }
#             },
#             "2024-06-07": {
#                 "Lighting": {
#                     "serbestTuketiciTuketimMiktari": 828,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 18328,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 606
#                 },
#                 "Other": {
#                     "serbestTuketiciTuketimMiktari": 0,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 10,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 803
#                 },
#                 "Household": {
#                     "serbestTuketiciTuketimMiktari": 352,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 28023,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 621182
#                 },
#                 "Industry": {
#                     "serbestTuketiciTuketimMiktari": 411813,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 382,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 21312
#                 },
#                 "Irrigation": {
#                     "serbestTuketiciTuketimMiktari": 55,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 16,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 323
#                 },
#                 "Commercial": {
#                     "serbestTuketiciTuketimMiktari": 618548,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 22710,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 382440
#                 }
#             }
#         },
#         "Istanbul_Asia": {
#             "2024-06-06": {
#                 "Lighting": {
#                     "serbestTuketiciTuketimMiktari": 80,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 15645,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 575
#                 },
#                 "Other": {
#                     "serbestTuketiciTuketimMiktari": 0,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 12,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 735
#                 },
#                 "Household": {
#                     "serbestTuketiciTuketimMiktari": 231,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 22742,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 368755
#                 },
#                 "Industry": {
#                     "serbestTuketiciTuketimMiktari": 147025,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 102,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 7807
#                 },
#                 "Irrigation": {
#                     "serbestTuketiciTuketimMiktari": 0,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 21,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 235
#                 },
#                 "Commercial": {
#                     "serbestTuketiciTuketimMiktari": 267838,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 4576,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 217244
#                 }
#             },
#             "2024-06-07": {
#                 "Lighting": {
#                     "serbestTuketiciTuketimMiktari": 80,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 15645,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 575
#                 },
#                 "Other": {
#                     "serbestTuketiciTuketimMiktari": 0,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 12,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 735
#                 },
#                 "Household": {
#                     "serbestTuketiciTuketimMiktari": 231,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 22742,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 368755
#                 },
#                 "Industry": {
#                     "serbestTuketiciTuketimMiktari": 147025,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 102,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 7807
#                 },
#                 "Irrigation": {
#                     "serbestTuketiciTuketimMiktari": 0,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 21,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 235
#                 },
#                 "Commercial": {
#                     "serbestTuketiciTuketimMiktari": 267838,
#                     "stHakkiBulunmayanTuketiciTuketimMiktari": 4576,
#                     "stHakkiniKullanmayanTuketiciTuketimMiktari": 217244
#                 }
#             }
#         }
#     }
# }
# ```
# 2025-05-28 23:29:15,484 - logger - INFO - Process decision and state updated
# 2025-05-28 23:29:15,485 - logger - INFO - Agent process_agent processing completed
# 2025-05-28 23:29:15,488 - logger - INFO - Entering process_router
# 2025-05-28 23:29:15,489 - logger - INFO - Processed decision: Visualization
# 2025-05-28 23:29:15,490 - logger - INFO - Valid process decision: Visualization
# 2025-05-28 23:29:15,494 - logger - INFO - Processing agent: visualization_agent
# ================================== Ai Message ==================================
# Name: process_agent
#
# {'next': 'Visualization', 'task': 'Verileri karşılaştırmalı olarak görselleştir (bar grafik ve/veya pasta grafik ile), Avrupa ve Asya yakalarının toplam elektrik tüketimini ve alt kırılımlarını (konut, sanayi, ticarethane vb.) iki gün için göster.'}
# Python REPL can execute arbitrary code. Use with caution.
# 2025-05-28 23:29:29,612 - logger - INFO - Visualization state updated
# 2025-05-28 23:29:29,613 - logger - INFO - Agent visualization_agent processing completed
# 2025-05-28 23:29:29,619 - logger - INFO - Processing agent: process_agent
# ================================== Ai Message ==================================
# Name: visualization_agent
#
# {
#   "visualizations": [
#     {
#       "figure": "Figure(1600x600)",
#       "description": "Bu grup çubuk grafiklerinde, İstanbul'un Avrupa ve Asya yakalarının 6 ve 7 Haziran 2024 tarihlerindeki elektrik tüketimi, sektör bazında (Aydınlatma, Diğer, Konut, Sanayi, Sulama, Ticarethane) karşılaştırmalı olarak gösterilmektedir. Her iki gün için ayrı grafik eksenleri kullanılmıştır. Grafikler, Avrupa yakasının tüm sektörlerde Asya'ya göre daha yüksek elektrik tüketimine sahip olduğunu açıkça ortaya koymaktadır. En yüksek tüketim konut ve ticarethane sektörlerinde gerçekleşmiştir."
#     }
#   ]
# }
# 2025-05-28 23:29:30,973 - logger - INFO - Process decision and state updated
# 2025-05-28 23:29:30,974 - logger - INFO - Agent process_agent processing completed
# 2025-05-28 23:29:30,978 - logger - INFO - Entering process_router
# 2025-05-28 23:29:30,979 - logger - INFO - Processed decision: Report
# 2025-05-28 23:29:30,980 - logger - INFO - Valid process decision: Report
# 2025-05-28 23:29:30,986 - logger - INFO - Processing agent: report_agent
# ================================== Ai Message ==================================
# Name: process_agent
#
# {'next': 'Report', 'task': 'Grafiklerdeki bulguları ve veri özetini içeren, Avrupa ve Asya yakalarının elektrik tüketimlerini iki gün için karşılaştıran kısa bir rapor hazırla.'}
# 2025-05-28 23:29:45,633 - logger - INFO - Report state updated
# 2025-05-28 23:29:45,635 - logger - INFO - Agent report_agent processing completed
# 2025-05-28 23:29:45,641 - logger - INFO - Processing agent: process_agent
# ================================== Ai Message ==================================
# Name: report_agent
#
# {
#     "report": {
#         "file_path": "./istanbul_electricity_consumption_report.txt",
#         "description": "İstanbul'un Avrupa ve Asya yakalarının elektrik tüketimlerini karşılaştıran bir rapor."
#     }
# }
# 2025-05-28 23:29:47,644 - logger - INFO - Process decision and state updated
# 2025-05-28 23:29:47,645 - logger - INFO - Agent process_agent processing completed
# 2025-05-28 23:29:47,650 - logger - INFO - Entering process_router
# 2025-05-28 23:29:47,651 - logger - INFO - Processed decision: FINISH
# 2025-05-28 23:29:47,653 - logger - INFO - Process decision is FINISH. Ending process.
# ================================== Ai Message ==================================
# Name: process_agent
#
# {'next': 'FINISH', 'task': 'Tüm adımlar tamamlandı. Görselleştirme ve rapor oluşturuldu. Süreci bitir.'}
